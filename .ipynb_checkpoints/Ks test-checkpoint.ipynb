# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## STEP 1 : Data Collection

# %%
filepath_House_Price = r"C:\Users\aakas\PythonStuff\Projects\Cali_HP\dataset\housing.csv"

# %%
houses = pd.read_csv(filepath_House_Price , header = 0 )

# %%
houses.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ### (i) To see number of null values , datatypes and memory usage

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ### (ii) Fetching numerical and categorical columns

# %%
def num_cat_col_list(DF) : 
    
    from pandas.api.types import is_string_dtype, is_numeric_dtype

    
    num_list = []
    cat_list = []

    for column in DF:

        if is_numeric_dtype(DF[column]):
            num_list.append(column)

        elif is_string_dtype(DF[column]):
            cat_list.append(column)

    return (num_list , cat_list)

# %%
num_list , cat_list = num_cat_col_list(houses)

print("Numerical column : ",num_list)
print()
print("Categorical column : ",cat_list)
# Out:
# Numerical column :  ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']
#
# Categorical column :  ['ocean_proximity']

# %% [markdown]
# ### (iii) Histogram-kde  for Numerical  attributes.

# %%
def hist_kde_plot(DF , num_list):
    
    total_size1 = len(num_list) 

    n_cols1 = 2
    n_rows1 = int(np.ceil(total_size1/n_cols1))

    fig1,axes1 = plt.subplots(nrows = n_rows1 ,ncols = n_cols1 , figsize = (12,18))

    i = 0
    j = 0

    fig1.suptitle("HISTOGRAM \n", fontweight="bold" ,fontsize=20)


    for col in num_list:


        axes2 = sns.histplot(ax = axes1[i,j], data = DF , x = col ,kde =  True ,bins = 20)
        fig1.tight_layout()

        axes2.set_title(f"{col}",fontweight="bold" ,fontsize=12)

        if j == n_cols1 -1:

            i +=1
            j = 0

        else :
            j+=1

# %%
hist_kde_plot(DF = houses, num_list=num_list)

# %% [markdown]
# ### INSIGHTS

# %% [markdown]
# **Right Skewed Distributed Features** : <br>
# total_rooms , total_bedrooms , population , households , median_income , median_house_value

# %%
rsc = ['total_rooms' , 'total_bedrooms' , 'population' , 'households' , 
       'median_income' , 'median_house_value']

# %% [markdown]
# The fit method returns three parameters: shape, loc, and scale. <br>
# The **shape** parameter corresponds to the shape parameter of the lognormal distribution. <br>
# The **loc** parameter represents the location parameter, which is the mean of the underlying normal
# distribution. <br>
# The **scale** parameter is related to the standard deviation of the underlying normal distribution.

# %%
def KStest(DF = None , right_skew_col =  None , ):
    
    passed = []
    failed = []
    
    for col in right_skew_col:
        
        print(f"Checking for feature :  {col}")
        
        num_arr = DF[col].dropna().to_numpy()
        
        # fitting lognormal to the distribution
        shape, loc, scale = stats.lognorm.fit(s_dist)
        
        results = stats.kstest(num_arr, 'lognorm', args=(shape, loc, scale))
        
        D_value = results[0]
        P_value = results[1]
        
        print("D-statistic : ",D_value)
        print("P-value : ",P_value)
        if D_value <= P_value :
            
            passed.append(col)
            print("Passed feature : ",col)
            
        else:
            
            failed.append(col)
            print("Failed feature : ",col)
            
        print()
    
    return passed,failed

# %%
KStest(DF = houses , right_skew_col =  rsc)
# Out:
# Checking for feature :  total_rooms
# D-statistic :  0.99950487959367
# P-value :  0.0
# Failed feature :  total_rooms
#
# Checking for feature :  total_bedrooms
# D-statistic :  0.9956810352581477
# P-value :  0.0
# Failed feature :  total_bedrooms
#
# Checking for feature :  population
# D-statistic :  0.998899230172118
# P-value :  0.0
# Failed feature :  population
#
# Checking for feature :  households
# D-statistic :  0.995499066839669
# P-value :  0.0
# Failed feature :  households
#
# Checking for feature :  median_income
# D-statistic :  0.011841880193782739
# P-value :  0.006075047861946109
# Failed feature :  median_income
#
# Checking for feature :  median_house_value
# D-statistic :  1.0
# P-value :  0.0
# Failed feature :  median_house_value
# ([],
#  ['total_rooms',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income',
#   'median_house_value'])

# %%
log_arr = np.random.lognormal(mean=0.0, sigma=1.0, size=1000)

# %%
shape, loc, scale = stats.lognorm.fit(log_arr)

# %%
shape, loc, scale
# Out:
# (0.9760482254027679, -0.006167187705619012, 1.0160973883267435)

# %%
stats.kstest(log_arr, 'lognorm', args=(shape, loc, scale))
# Out:
# KstestResult(statistic=0.014146883010382194, pvalue=0.986614878512662, statistic_location=0.5890167055113995, statistic_sign=1)

# %%
stats.kstest(houses['median_income'].dropna().to_numpy()
             , 'norm')
# Out:
# KstestResult(statistic=0.8953266796146241, pvalue=0.0, statistic_location=1.5809, statistic_sign=-1)

# %%
stats.kstest(houses['median_house_value'].dropna().to_numpy()
             , 'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0, statistic_location=14999.0, statistic_sign=-1)
